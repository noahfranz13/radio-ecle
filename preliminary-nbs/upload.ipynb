# %%
import otter
import os

# %%
db = otter.Otter(datadir=os.path.join(os.getcwd(), "private_otter_data"))

# %%
db.upload(testing=False)
# Out:
# [ArangoDoc '_id: vetting/44464, _key: 44464, _rev: _i23YcrS---': <store: {'name': <store: {'default_name': 'AT2021dms', 'alias': [{'value': 'AT2021dms', 'reference': ['2024MNRAS.528.4775H']}]}>, 'coordinate': [{'ra': '03:21:24.069', 'dec': '-11:08:45.71', 'ra_units': 'hour', 'dec_units': 'degree', 'reference': ['2024MNRAS.528.4775H'], 'coordinate_type': 'equitorial'}], 'distance': [{'value': 0.031102, 'reference': ['2024MNRAS.528.4775H'], 'computed': False, 'distance_type': 'redshift'}], 'classification': [{'object_class': 'TDE', 'confidence': 1, 'reference': ['2024MNRAS.528.4775H']}], 'date_reference': [{'value': '2459266.645706', 'date_format': 'jd', 'reference': ['2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '2021TNSTR.542....1F', '
# ...
